# %%
import math
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
xs = np.arange(0, 10, .1)
ys_power = xs**2
ys_exp = 2**xs

plt.plot(xs, ys_power, label='power', c='blue')
plt.legend()
plt.plot(xs, ys_exp, label='exponential', c='red')
plt.legend()
